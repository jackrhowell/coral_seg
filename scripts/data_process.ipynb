# %%
#Need to remove/Fix M8-16, M43-5, M43-8, M43-2, M18-1, M11-2, MC297_M6-5, M43-6, M43-11 and M18-8

from __future__ import annotations

from pathlib import Path
import traceback
import numpy as np
from PIL import Image
import cairosvg
import xml.etree.ElementTree as ET
from skimage.morphology import dilation, disk

# %%
broken_folders = [
    "M18-6","MC297_M6-5_OIII_NF22","M43-6"
]

# %%
from pathlib import Path
from PIL import Image
import numpy as np

root_dir = Path("/home/jrhowell/sadow_koastore/shared/coral_seg/data")

print("\n=== FINAL SEG MASK CHECK ===\n")

for name in broken_folders:
    mask_path = root_dir / name / "seg_r10.png"

    if not mask_path.exists():
        print(f"{name}: MISSING MASK")
        continue

    mask = np.array(Image.open(mask_path))
    unique_vals = np.unique(mask)

    print(f"{name}: {unique_vals.tolist()}")
# Out:
# === FINAL SEG MASK CHECK ===
#
# M18-6: [4]
# MC297_M6-5_OIII_NF22: [0]
# M43-6: [4]

# %%
LABELS = {"nv": 1, "nh": 2, "hy": 3, "st/zo": 4}
PRIORITY_HIGH_TO_LOW = ["st/zo", "hy", "nh", "nv"]  # high wins (written last)

IMAGE_LAYER_LABELS = {"image", "Image"}

INK_LABEL = "{http://www.inkscape.org/namespaces/inkscape}label"
INK_GROUPMODE = "{http://www.inkscape.org/namespaces/inkscape}groupmode"

FILENAME_SAFE = {"st/zo": "st_zo"}
REVERSE_FILENAME_SAFE = {v: k for k, v in FILENAME_SAFE.items()}

# Visualization colors (match your overlay colors)
OVERLAY_COLORS = {
    "nv": (0, 255, 0),    # green
    "nh": (255, 0, 0),    # red
    "hy": (255, 255, 0),  # yellow
    "st/zo": (0, 0, 255), # blue
}

# Seg-color (by class id) – consistent with LABELS above
SEG_COLORS = {
    0: (0, 0, 0),        # background
    1: (0, 255, 0),      # nv
    2: (255, 0, 0),      # nh
    3: (255, 255, 0),    # hy
    4: (0, 0, 255),      # st/zo
}

# %%
def parse_svg(svg_path: Path) -> ET.ElementTree:
    return ET.parse(svg_path)

def is_layer_group(el: ET.Element) -> bool:
    return el.tag.endswith("g") and el.attrib.get(INK_GROUPMODE) == "layer"

def layer_label(el: ET.Element) -> str | None:
    return el.attrib.get(INK_LABEL) or el.attrib.get("id") or el.attrib.get("class")

def find_layer_groups(tree: ET.ElementTree) -> list[ET.Element]:
    root = tree.getroot()
    return [el for el in root.iter() if is_layer_group(el)]

def find_image_and_class_layers(layers: list[ET.Element]) -> tuple[ET.Element, dict[str, ET.Element]]:
    image_layer = None
    class_layers: dict[str, ET.Element] = {}

    for layer in layers:
        lab = layer_label(layer)
        if not lab:
            continue
        s = lab.strip()

        if s.lower() in {x.lower() for x in IMAGE_LAYER_LABELS}:
            image_layer = layer
            continue

        key = s.lower()
        if key in LABELS:
            class_layers[key] = layer

    if image_layer is None:
        raise ValueError(f"No image layer found. Layer labels present: {[layer_label(l) for l in layers]}")

    return image_layer, class_layers

def set_layer_visibility(layers: list[ET.Element], visible: set[ET.Element]) -> None:
    for layer in layers:
        layer.attrib["style"] = "display:inline !important" if layer in visible else "display:none !important"

def write_svg(tree: ET.ElementTree, out_path: Path) -> None:
    out_path.parent.mkdir(parents=True, exist_ok=True)
    tree.write(out_path, encoding="utf-8", xml_declaration=True)

def svg_to_png(svg_path: Path, png_path: Path, scale: float = 1.0) -> None:
    png_path.parent.mkdir(parents=True, exist_ok=True)
    cairosvg.svg2png(
        url=str(svg_path),
        write_to=str(png_path),
        scale=scale
    )

def png_to_rgb_inplace(png_path: Path) -> None:
    Image.open(png_path).convert("RGB").save(png_path)

def load_binary_mask(png_path: Path) -> np.ndarray:
    arr = np.array(Image.open(png_path))

    # If RGBA → use alpha channel (best case)
    if arr.ndim == 3 and arr.shape[-1] == 4:
        return arr[..., 3] > 127

    # Otherwise convert to grayscale and threshold
    if arr.ndim == 3:
        gray = arr[..., :3].mean(axis=-1)
    else:
        gray = arr

    return gray > 127

# %%
def combine_per_class_masks(mask_paths: dict[str, Path], radius: int) -> np.ndarray:
    sample = np.array(Image.open(next(iter(mask_paths.values()))))
    H, W = sample.shape[:2]
    seg = np.zeros((H, W), dtype=np.uint8)

    for k in reversed(PRIORITY_HIGH_TO_LOW):

        p = mask_paths.get(k)
        if not p or not p.exists():
            continue

        print(f"\n--- DEBUG {k} ---")
        print(f"path: {p}")

        arr = np.array(Image.open(p))
        print(f"{k}: shape={arr.shape}, dtype={arr.dtype}, min={arr.min()}, max={arr.max()}")

        if arr.ndim == 3:
            if arr.shape[-1] == 4:
                print(f"{k}: unique alpha values:", np.unique(arr[..., 3])[:10])
            else:
                print(f"{k}: sample pixel:", arr[0, 0])
        else:
            print(f"{k}: unique values:", np.unique(arr)[:10])

        binary = load_binary_mask(p)
        print(f"{k} BEFORE dilation: {binary.mean():.4f}")

        if radius and radius > 0:
            binary = dilation(binary, disk(radius))

        print(f"{k} AFTER dilation:  {binary.mean():.4f}")

        seg[binary] = LABELS[k]

    return seg

def save_color_segmentation(seg: np.ndarray, out_png: Path) -> None:
    h, w = seg.shape
    rgb = np.zeros((h, w, 3), dtype=np.uint8)
    for k, color in SEG_COLORS.items():
        rgb[seg == k] = color
    Image.fromarray(rgb).save(out_png)

def overlay_masks_on_image(
    image_png: Path,
    mask_paths: dict[str, Path],
    out_png: Path,
    radius: int = 0,
    alpha: float = 0.5,
) -> None:
    img = np.array(Image.open(image_png).convert("RGB"))
    overlay = img.copy()

    for key, color in OVERLAY_COLORS.items():
        p = mask_paths.get(key)
        if not p or not p.exists():
            continue

        mask = load_binary_mask(p)
        if radius > 0:
            mask = dilation(mask, disk(radius))

        overlay[mask] = ((1 - alpha) * overlay[mask] + alpha * np.array(color)).astype(np.uint8)

    Image.fromarray(overlay).save(out_png)

# %%
from tempfile import TemporaryDirectory

def process_svg(
    svg_path: Path,
    out_root: Path,
    r_extra: int = 0,
    scale: float = 0.5,   # low-res scale
) -> Path:
    """
    Outputs:
      - image.png        (low-res, scaled)
      - high_image.png   (full-res)
      - seg_r{r_extra}.png (matches image.png)
    """
    stem = svg_path.stem
    out_dir = out_root / stem
    out_dir.mkdir(parents=True, exist_ok=True)

    # Detect layers
    tree0 = parse_svg(svg_path)
    layers0 = find_layer_groups(tree0)
    img_layer0, class_layers0 = find_image_and_class_layers(layers0)

    if not class_layers0:
        raise ValueError(
            f"No class layers found. "
            f"Layer labels present: {[layer_label(l) for l in layers0]}"
        )

    # ---------- IMAGE LAYER ----------
    tree_img = parse_svg(svg_path)
    layers_img = find_layer_groups(tree_img)
    img_layer, _ = find_image_and_class_layers(layers_img)
    set_layer_visibility(layers_img, visible={img_layer})

    image_svg = out_dir / "image_only.svg"
    write_svg(tree_img, image_svg)

    # High-res image
    high_image_png = out_dir / "high_image.png"
    svg_to_png(image_svg, high_image_png, scale=1.0)
    png_to_rgb_inplace(high_image_png)

    # Low-res image
    image_png = out_dir / "image.png"
    svg_to_png(image_svg, image_png, scale=scale)
    png_to_rgb_inplace(image_png)

    # Remove temp svg
    image_svg.unlink(missing_ok=True)

    # ---------- MASKS → SEG ----------
    with TemporaryDirectory() as tmpdir:
        tmpdir = Path(tmpdir)
        mask_paths: dict[str, Path] = {}

        for k in class_layers0.keys():
            tree_k = parse_svg(svg_path)
            layers_k = find_layer_groups(tree_k)
            _, class_layers_k = find_image_and_class_layers(layers_k)
            layer_el = class_layers_k.get(k)
            if layer_el is None:
                continue

            set_layer_visibility(layers_k, visible={layer_el})

            safe = FILENAME_SAFE.get(k, k)
            k_svg = tmpdir / f"{safe}.svg"
            k_png = out_dir / f"debug_{safe}.png"

            write_svg(tree_k, k_svg)
            svg_to_png(k_svg, k_png, scale=scale)

            mask_paths[k] = k_png

        if not mask_paths:
            raise ValueError("No mask PNGs produced.")

        seg = combine_per_class_masks(mask_paths, radius=r_extra)
        seg_png = out_dir / f"seg_r{r_extra}.png"
        Image.fromarray(seg).save(seg_png)

    return out_dir

# %%
def batch_process(
    svg_dir: Path,
    out_root: Path,
    r_extra: int = 10,
    scale: float = 0.25,
    skip_existing: bool = True,
) -> None:
    svgs = sorted(p for p in svg_dir.rglob("*.svg") if "_gr.svg" not in p.name.lower())
    print("Found:", len(svgs))

    ok = 0
    failed = 0
    skipped = 0

    for svg in svgs:
        try:
            out_dir = out_root / svg.stem

            # optional: skip if already done
            if skip_existing and (out_dir / f"seg_r{r_extra}.png").exists() and (out_dir / "image.png").exists():
                skipped += 1
                continue

            process_svg(
                svg_path=svg,
                out_root=out_root,
                r_extra=r_extra,
                scale=scale,
            )
            ok += 1

        except Exception as e:
            failed += 1
            print(f"FAILED: {svg}")
            print(" ", repr(e))
            # uncomment for full trace:
            # print(traceback.format_exc())

    print(f"Done. OK={ok}  SKIPPED={skipped}  FAILED={failed}")
    print("Output root:", out_root)

# %%
svg_dir = Path("/home/jrhowell/benthic_ecology_group/Jack/coral_seg/deprecated/four_layer_images6")
out_root = Path("/home/jrhowell/benthic_ecology_group/Jack/coral_seg/data")

for name in broken_folders:
    svg_path = next(svg_dir.rglob(f"{name}.svg"), None)

    if svg_path is None:
        print(f"{name}: SVG NOT FOUND")
        continue

    print(f"\nProcessing {name}")
    process_svg(svg_path, out_root, r_extra=10, scale=0.25)
# Out:
# Processing M18-6
#
# --- DEBUG nv ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/M18-6/debug_nv.png
# nv: shape=(1152, 1728, 4), dtype=uint8, min=0, max=255
# nv: unique alpha values: [254 255]
# nv BEFORE dilation: 1.0000
# nv AFTER dilation:  1.0000
#
# --- DEBUG nh ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/M18-6/debug_nh.png
# nh: shape=(1152, 1728, 4), dtype=uint8, min=0, max=255
# nh: unique alpha values: [254 255]
# nh BEFORE dilation: 1.0000
# nh AFTER dilation:  1.0000
#
# --- DEBUG hy ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/M18-6/debug_hy.png
# hy: shape=(1152, 1728, 4), dtype=uint8, min=4, max=255
# hy: unique alpha values: [254 255]
# hy BEFORE dilation: 1.0000
# hy AFTER dilation:  1.0000
#
# --- DEBUG st/zo ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/M18-6/debug_st_zo.png
# st/zo: shape=(1152, 1728, 4), dtype=uint8, min=4, max=255
# st/zo: unique alpha values: [254 255]
# st/zo BEFORE dilation: 1.0000
# st/zo AFTER dilation:  1.0000
#
# Processing MC297_M6-5_OIII_NF22
#
# --- DEBUG nv ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/MC297_M6-5_OIII_NF22/debug_nv.png
# nv: shape=(1000, 1500, 4), dtype=uint8, min=0, max=0
# nv: unique alpha values: [0]
# nv BEFORE dilation: 0.0000
# nv AFTER dilation:  0.0000
#
# --- DEBUG nh ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/MC297_M6-5_OIII_NF22/debug_nh.png
# nh: shape=(1000, 1500, 4), dtype=uint8, min=0, max=0
# nh: unique alpha values: [0]
# nh BEFORE dilation: 0.0000
# nh AFTER dilation:  0.0000
#
# --- DEBUG hy ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/MC297_M6-5_OIII_NF22/debug_hy.png
# hy: shape=(1000, 1500, 4), dtype=uint8, min=0, max=0
# hy: unique alpha values: [0]
# hy BEFORE dilation: 0.0000
# hy AFTER dilation:  0.0000
#
# --- DEBUG st/zo ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/MC297_M6-5_OIII_NF22/debug_st_zo.png
# st/zo: shape=(1000, 1500, 4), dtype=uint8, min=0, max=0
# st/zo: unique alpha values: [0]
# st/zo BEFORE dilation: 0.0000
# st/zo AFTER dilation:  0.0000
#
# Processing M43-6
#
# --- DEBUG nv ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/M43-6/debug_nv.png
# nv: shape=(1152, 1728, 4), dtype=uint8, min=0, max=255
# nv: unique alpha values: [254 255]
# nv BEFORE dilation: 1.0000
# nv AFTER dilation:  1.0000
#
# --- DEBUG nh ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/M43-6/debug_nh.png
# nh: shape=(1152, 1728, 4), dtype=uint8, min=0, max=255
# nh: unique alpha values: [254 255]
# nh BEFORE dilation: 1.0000
# nh AFTER dilation:  1.0000
#
# --- DEBUG hy ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/M43-6/debug_hy.png
# hy: shape=(1152, 1728, 4), dtype=uint8, min=3, max=255
# hy: unique alpha values: [254 255]
# hy BEFORE dilation: 1.0000
# hy AFTER dilation:  1.0000
#
# --- DEBUG st/zo ---
# path: /home/jrhowell/benthic_ecology_group/Jack/coral_seg/data/M43-6/debug_st_zo.png
# st/zo: shape=(1152, 1728, 4), dtype=uint8, min=3, max=255
# st/zo: unique alpha values: [254 255]
# st/zo BEFORE dilation: 1.0000
# st/zo AFTER dilation:  1.0000

# %%
if __name__ == "__main__":
    svg_dir = Path("/home/jrhowell/benthic_ecology_group/Jack/coral_seg/deprecated/four_layer_images6")
    out_root = Path("/home/jrhowell/benthic_ecology_group/Jack/coral_seg/data")

    batch_process(svg_dir, out_root, r_extra=10, scale=0.25)
# Out:
# Found: 199
# nv before dilation: 0.0055
# nv after dilation:  0.0388
# nh before dilation: 0.0001
# nh after dilation:  0.0010
# hy before dilation: 0.0000
# hy after dilation:  0.0000
# st/zo before dilation: 0.0000
# st/zo after dilation:  0.0000
# nv before dilation: 0.0068
# nv after dilation:  0.0453
# nh before dilation: 0.0000
# nh after dilation:  0.0000
# hy before dilation: 0.0000
# hy after dilation:  0.0000
# st/zo before dilation: 0.0000
# st/zo after dilation:  0.0000
# nv before dilation: 0.0019
# nv after dilation:  0.0136
# nh before dilation: 0.0000
# nh after dilation:  0.0006
# hy before dilation: 0.0000
# hy after dilation:  0.0000
# st/zo before dilation: 0.0000
# st/zo after dilation:  0.0000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.conda/envs/coral_seg/lib/python3.10/site-packages/PIL/ImageFile.py:660, in _save(im, fp, tile, bufsize)
#     659 try:
# --> 660     fh = fp.fileno()
#     661     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 svg_dir = Path("/home/jrhowell/benthic_ecology_group/Jack/coral_seg/deprecated/four_layer_images6")
#       3 out_root = Path("/home/jrhowell/benthic_ecology_group/Jack/coral_seg/coral_seg/data")
# ----> 5 batch_process(svg_dir, out_root, r_extra=10, scale=0.25)
#
# Cell In[6], line 24, in batch_process(svg_dir, out_root, r_extra, scale, skip_existing)
#      21         skipped += 1
#      22         continue
# ---> 24     process_svg(
#      25         svg_path=svg,
#      26         out_root=out_root,
#      27         r_extra=r_extra,
#      28         scale=scale,
#      29     )
#      30     ok += 1
#      32 except Exception as e:
#
# Cell In[5], line 42, in process_svg(svg_path, out_root, r_extra, scale)
#      40 high_image_png = out_dir / "high_image.png"
#      41 svg_to_png(image_svg, high_image_png, scale=1.0)
# ---> 42 png_to_rgb_inplace(high_image_png)
#      44 # Low-res image
#      45 image_png = out_dir / "image.png"
#
# Cell In[3], line 54, in png_to_rgb_inplace(png_path)
#      53 def png_to_rgb_inplace(png_path: Path) -> None:
# ---> 54     Image.open(png_path).convert("RGB").save(png_path)
#
# File ~/.conda/envs/coral_seg/lib/python3.10/site-packages/PIL/Image.py:2590, in Image.save(self, fp, format, **params)
#    2587     fp = cast(IO[bytes], fp)
#    2589 try:
# -> 2590     save_handler(self, fp, filename)
#    2591 except Exception:
#    2592     if open_fp:
#
# File ~/.conda/envs/coral_seg/lib/python3.10/site-packages/PIL/PngImagePlugin.py:1508, in _save(im, fp, filename, chunk, save_all)
#    1506 if single_im:
#    1507     _apply_encoderinfo(single_im, im.encoderinfo)
# -> 1508     ImageFile._save(
#    1509         single_im,
#    1510         cast(IO[bytes], _idat(fp, chunk)),
#    1511         [ImageFile._Tile("zip", (0, 0) + single_im.size, 0, rawmode)],
#    1512     )
#    1514 if info:
#    1515     for info_chunk in info.chunks:
#
# File ~/.conda/envs/coral_seg/lib/python3.10/site-packages/PIL/ImageFile.py:664, in _save(im, fp, tile, bufsize)
#     662     _encode_tile(im, fp, tile, bufsize, fh)
#     663 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 664     _encode_tile(im, fp, tile, bufsize, None, exc)
#     665 if hasattr(fp, "flush"):
#     666     fp.flush()
#
# File ~/.conda/envs/coral_seg/lib/python3.10/site-packages/PIL/ImageFile.py:690, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     687 if exc:
#     688     # compress to Python file-compatible object
#     689     while True:
# --> 690         errcode, data = encoder.encode(bufsize)[1:]
#     691         fp.write(data)
#     692         if errcode:
#
# KeyboardInterrupt:

# %%
from pathlib import Path
import shutil

# repo root (pointing at your data directory)
REPO_ROOT = Path("/home/jrhowell/benthic_ecology_group/Jack/coral_seg/coral_seg/data")

# where you want to store the high-res images
ARCHIVE_DIR = Path("/home/jrhowell/benthic_ecology_group/Jack/coral_seg/high_archive")
ARCHIVE_DIR.mkdir(parents=True, exist_ok=True)

# find and move all high_image.png files
for img in REPO_ROOT.rglob("high_image.png"):
    rel = img.relative_to(REPO_ROOT)
    target = ARCHIVE_DIR / rel

    target.parent.mkdir(parents=True, exist_ok=True)

    # move (use copy2 if you want to keep originals)
    shutil.move(img, target)

print("High-resolution images archived successfully.")
# Out:
# High-resolution images archived successfully.
