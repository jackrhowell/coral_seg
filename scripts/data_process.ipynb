# %%
from __future__ import annotations

from pathlib import Path
from tempfile import TemporaryDirectory
import traceback
import numpy as np
from PIL import Image
import cairosvg
import xml.etree.ElementTree as ET
from skimage.morphology import dilation, disk
import matplotlib.pyplot as plt

# %%
# ---------- Normal pipeline configuration ----------
SVG_DIR = Path("/home/jrhowell/benthic_ecology_group/Jack/coral_seg/deprecated/four_layer_images6")
OUT_ROOT = Path("/home/jrhowell/sadow_koastore/shared/coral_seg/data")
R_EXTRA = 10
SCALE = 0.25
SKIP_EXISTING = True

# ---------- Optional debug configuration ----------
#add files if needed
DEBUG_BROKEN_FOLDERS = [
]

DEBUG_DATA_ROOT = OUT_ROOT

# %%
LABELS = {"nv": 1, "nh": 2, "hy": 3, "st/zo": 4}
PRIORITY_HIGH_TO_LOW = ["st/zo", "hy", "nh", "nv"]  # high wins (written last)

IMAGE_LAYER_LABELS = {"image", "Image"}

INK_LABEL = "{http://www.inkscape.org/namespaces/inkscape}label"
INK_GROUPMODE = "{http://www.inkscape.org/namespaces/inkscape}groupmode"

FILENAME_SAFE = {"st/zo": "st_zo"}
REVERSE_FILENAME_SAFE = {v: k for k, v in FILENAME_SAFE.items()}

OVERLAY_COLORS = {
    "nv": (0, 255, 0),
    "nh": (255, 0, 0),
    "hy": (255, 255, 0),
    "st/zo": (0, 0, 255),
}

SEG_COLORS = {
    0: (0, 0, 0),
    1: (0, 255, 0),
    2: (255, 0, 0),
    3: (255, 255, 0),
    4: (0, 0, 255),
}

# %%
def parse_svg(svg_path: Path) -> ET.ElementTree:
    return ET.parse(svg_path)


def is_layer_group(el: ET.Element) -> bool:
    return el.tag.endswith("g") and el.attrib.get(INK_GROUPMODE) == "layer"


def layer_label(el: ET.Element) -> str | None:
    return el.attrib.get(INK_LABEL) or el.attrib.get("id") or el.attrib.get("class")


def keep_only_layer(tree: ET.ElementTree, keep_key: str) -> None:
    """Keep only top-level infrastructure plus the requested class layer."""
    root = tree.getroot()
    keep_tags = {"defs", "style", "metadata", "namedview"}

    for child in list(root):
        local_tag = child.tag.split("}")[-1]

        if local_tag in keep_tags:
            continue

        if is_layer_group(child):
            lab = layer_label(child)
            if lab is not None and lab.strip().lower() == keep_key.lower():
                continue

        root.remove(child)


def find_layer_groups(tree: ET.ElementTree) -> list[ET.Element]:
    root = tree.getroot()
    return [el for el in root.iter() if is_layer_group(el)]


def find_image_and_class_layers(layers: list[ET.Element]) -> tuple[ET.Element, dict[str, ET.Element]]:
    image_layer = None
    class_layers: dict[str, ET.Element] = {}

    for layer in layers:
        lab = layer_label(layer)
        if not lab:
            continue
        s = lab.strip()

        if s.lower() in {x.lower() for x in IMAGE_LAYER_LABELS}:
            image_layer = layer
            continue

        key = s.lower()
        if key in LABELS:
            class_layers[key] = layer

    if image_layer is None:
        raise ValueError(f"No image layer found. Layer labels present: {[layer_label(l) for l in layers]}")

    return image_layer, class_layers


def set_layer_visibility(layers: list[ET.Element], visible: set[ET.Element]) -> None:
    for layer in layers:
        layer.attrib["style"] = "display:inline !important" if layer in visible else "display:none !important"


def write_svg(tree: ET.ElementTree, out_path: Path) -> None:
    out_path.parent.mkdir(parents=True, exist_ok=True)
    tree.write(out_path, encoding="utf-8", xml_declaration=True)


def svg_to_png(svg_path: Path, png_path: Path, scale: float = 1.0) -> None:
    png_path.parent.mkdir(parents=True, exist_ok=True)
    cairosvg.svg2png(url=str(svg_path), write_to=str(png_path), scale=scale)


def png_to_rgb_inplace(png_path: Path) -> None:
    Image.open(png_path).convert("RGB").save(png_path)


def load_binary_mask(png_path: Path) -> np.ndarray:
    arr = np.array(Image.open(png_path))

    if arr.ndim == 3 and arr.shape[-1] == 4:
        return arr[..., 3] > 127

    if arr.ndim == 3:
        gray = arr[..., :3].mean(axis=-1)
    else:
        gray = arr

    return gray > 127


def save_color_segmentation(seg: np.ndarray, out_png: Path) -> None:
    h, w = seg.shape
    rgb = np.zeros((h, w, 3), dtype=np.uint8)
    for k, color in SEG_COLORS.items():
        rgb[seg == k] = color
    Image.fromarray(rgb).save(out_png)


def overlay_masks_on_image(
    image_png: Path,
    mask_paths: dict[str, Path],
    out_png: Path,
    radius: int = 0,
    alpha: float = 0.5,
) -> None:
    img = np.array(Image.open(image_png).convert("RGB"))
    overlay = img.copy()

    for key, color in OVERLAY_COLORS.items():
        p = mask_paths.get(key)
        if not p or not p.exists():
            continue

        mask = load_binary_mask(p)
        if radius > 0:
            mask = dilation(mask, disk(radius))

        overlay[mask] = ((1 - alpha) * overlay[mask] + alpha * np.array(color)).astype(np.uint8)

    Image.fromarray(overlay).save(out_png)

# %%
def combine_per_class_masks(
    mask_paths: dict[str, Path],
    radius: int,
    debug: bool = False,
) -> np.ndarray:
    sample = np.array(Image.open(next(iter(mask_paths.values()))))
    h, w = sample.shape[:2]
    seg = np.zeros((h, w), dtype=np.uint8)

    for k in reversed(PRIORITY_HIGH_TO_LOW):
        p = mask_paths.get(k)
        if not p or not p.exists():
            continue

        if debug:
            print(f"\n--- DEBUG {k} ---")
            print(f"path: {p}")
            arr = np.array(Image.open(p))
            print(f"{k}: shape={arr.shape}, dtype={arr.dtype}, min={arr.min()}, max={arr.max()}")
            if arr.ndim == 3 and arr.shape[-1] == 4:
                print(f"{k}: unique alpha values:", np.unique(arr[..., 3])[:10])
            elif arr.ndim == 3:
                print(f"{k}: sample pixel:", arr[0, 0])
            else:
                print(f"{k}: unique values:", np.unique(arr)[:10])

        binary = load_binary_mask(p)

        if debug:
            print(f"{k} BEFORE dilation: {binary.mean():.4f}")

        if radius and radius > 0:
            binary = dilation(binary, disk(radius))

        if debug:
            print(f"{k} AFTER dilation:  {binary.mean():.4f}")

        seg[binary] = LABELS[k]

    return seg


def process_svg(
    svg_path: Path,
    out_root: Path,
    r_extra: int = 0,
    scale: float = 0.5,
    debug: bool = False,
) -> Path:
    """Process one SVG into image + segmentation outputs."""
    stem = svg_path.stem
    out_dir = out_root / stem
    out_dir.mkdir(parents=True, exist_ok=True)

    tree0 = parse_svg(svg_path)
    layers0 = find_layer_groups(tree0)
    _, class_layers0 = find_image_and_class_layers(layers0)

    if not class_layers0:
        raise ValueError(
            f"No class layers found. Layer labels present: {[layer_label(l) for l in layers0]}"
        )

    # Export image layer.
    tree_img = parse_svg(svg_path)
    layers_img = find_layer_groups(tree_img)
    img_layer, _ = find_image_and_class_layers(layers_img)
    set_layer_visibility(layers_img, visible={img_layer})

    image_svg = out_dir / "image_only.svg"
    write_svg(tree_img, image_svg)

    #high_image_png = out_dir / "high_image.png"
    #svg_to_png(image_svg, high_image_png, scale=1.0)
    #png_to_rgb_inplace(high_image_png)

    image_png = out_dir / "image.png"
    svg_to_png(image_svg, image_png, scale=scale)
    png_to_rgb_inplace(image_png)

    image_svg.unlink(missing_ok=True)

    # Export class masks.
    with TemporaryDirectory() as tmpdir_name:
        tmpdir = Path(tmpdir_name)
        mask_paths: dict[str, Path] = {}

        for k in class_layers0.keys():
            tree_k = parse_svg(svg_path)
            keep_only_layer(tree_k, k)

            safe = FILENAME_SAFE.get(k, k)
            k_svg = tmpdir / f"{safe}.svg"
            k_png = (out_dir / f"debug_{safe}.png") if debug else (tmpdir / f"{safe}.png")

            write_svg(tree_k, k_svg)
            svg_to_png(k_svg, k_png, scale=scale)
            mask_paths[k] = k_png

        if not mask_paths:
            raise ValueError("No mask PNGs produced.")

        seg = combine_per_class_masks(mask_paths, radius=r_extra, debug=debug)
        seg_png = out_dir / f"seg_r{r_extra}.png"
        Image.fromarray(seg).save(seg_png)

    return out_dir


def batch_process(
    svg_dir: Path,
    out_root: Path,
    r_extra: int = 10,
    scale: float = 0.25,
    skip_existing: bool = True,
    debug: bool = False,
) -> None:
    svgs = sorted(p for p in svg_dir.rglob("*.svg") if "_gr.svg" not in p.name.lower())
    print("Found:", len(svgs))

    ok = 0
    failed = 0
    skipped = 0

    for svg in svgs:
        try:
            out_dir = out_root / svg.stem
            if skip_existing and (out_dir / f"seg_r{r_extra}.png").exists() and (out_dir / "image.png").exists():
                skipped += 1
                continue

            process_svg(
                svg_path=svg,
                out_root=out_root,
                r_extra=r_extra,
                scale=scale,
                debug=debug,
            )
            ok += 1
        except Exception as e:
            failed += 1
            print(f"FAILED: {svg}")
            print(" ", repr(e))
            if debug:
                print(traceback.format_exc())

    print(f"Done. OK={ok}  SKIPPED={skipped}  FAILED={failed}")
    print("Output root:", out_root)

# %%
batch_process(
    svg_dir=SVG_DIR,
    out_root=OUT_ROOT,
    r_extra=R_EXTRA,
    scale=SCALE,
    skip_existing=SKIP_EXISTING,
    debug=False,
)
# Out:
# Found: 199
# Done. OK=199  SKIPPED=0  FAILED=0
# Output root: /home/jrhowell/sadow_koastore/shared/coral_seg/data

# %%
#For Debugging

def summarize_svg_layers(svg_path: Path) -> None:
    tree = parse_svg(svg_path)
    layers = find_layer_groups(tree)

    print(f"\nSVG: {svg_path.name}")
    print(f"Found {len(layers)} layer groups")

    for layer in layers:
        lab = layer_label(layer)
        n_children = len(list(layer))
        print(f"  label={lab!r}, children={n_children}")


def summarize_layer_children(svg_path: Path) -> None:
    tree = parse_svg(svg_path)
    layers = find_layer_groups(tree)

    print(f"\nDETAILS: {svg_path.name}")
    for layer in layers:
        lab = layer_label(layer)
        print(f"\nLayer {lab!r}")
        children = list(layer)
        print(f"  number of children: {len(children)}")
        for child in children[:10]:
            print(f"   tag={child.tag.split('}')[-1]}, attrs={list(child.attrib.keys())[:8]}")


def find_empty_svgs(svg_dir: Path) -> tuple[list[str], list[tuple[str, dict[str, int]]]]:
    empty_svgs = []
    partial_empty = []

    for svg_path in svg_dir.rglob("*.svg"):
        try:
            tree = parse_svg(svg_path)
            layers = find_layer_groups(tree)
            _, class_layers = find_image_and_class_layers(layers)
            counts = {k: len(list(layer)) for k, layer in class_layers.items()}

            if sum(counts.values()) == 0:
                empty_svgs.append(svg_path.name)
            elif any(v == 0 for v in counts.values()):
                partial_empty.append((svg_path.name, counts))
        except Exception as e:
            print(f"Error reading {svg_path.name}: {e}")

    return empty_svgs, partial_empty


def check_final_seg_masks(data_root: Path, folder_names: list[str], r_extra: int = 10) -> None:
    print("\n=== FINAL SEG MASK CHECK ===\n")
    for name in folder_names:
        mask_path = data_root / name / f"seg_r{r_extra}.png"
        if not mask_path.exists():
            print(f"{name}: MISSING MASK")
            continue
        mask = np.array(Image.open(mask_path))
        print(f"{name}: {np.unique(mask).tolist()}")


def process_debug_files(
    folder_names: list[str],
    svg_dir: Path = SVG_DIR,
    out_root: Path = OUT_ROOT,
    r_extra: int = R_EXTRA,
    scale: float = SCALE,
) -> None:
    for name in folder_names:
        svg_path = next(svg_dir.rglob(f"{name}.svg"), None)
        if svg_path is None:
            print(f"{name}: SVG NOT FOUND")
            continue

        print(f"\nProcessing {name}")
        process_svg(svg_path, out_root, r_extra=r_extra, scale=scale, debug=True)


def visualize_debug_outputs(folder_name: str, data_root: Path = OUT_ROOT, r_extra: int = R_EXTRA) -> None:
    folder = data_root / folder_name
    image = np.array(Image.open(folder / "image.png").convert("RGB"))

    debug_paths = {
        "nv": folder / "debug_nv.png",
        "nh": folder / "debug_nh.png",
        "hy": folder / "debug_hy.png",
        "st/zo": folder / "debug_st_zo.png",
    }

    fig, axes = plt.subplots(2, 3, figsize=(15, 10))

    axes[0, 0].imshow(image)
    axes[0, 0].set_title("Image")
    axes[0, 0].axis("off")

    for ax, (label, path) in zip(axes.flat[1:5], debug_paths.items()):
        arr = np.array(Image.open(path))
        alpha = arr[..., 3] if arr.ndim == 3 and arr.shape[-1] == 4 else arr
        ax.imshow(alpha, cmap="gray")
        ax.set_title(f"{label} alpha")
        ax.axis("off")

    seg_path = folder / f"seg_r{r_extra}.png"
    if seg_path.exists():
        seg = np.array(Image.open(seg_path))
        axes[1, 2].imshow(seg, cmap="tab10", interpolation="nearest")
        axes[1, 2].set_title("Final segmentation")
        axes[1, 2].axis("off")
    else:
        axes[1, 2].axis("off")

    plt.tight_layout()
    plt.show()
